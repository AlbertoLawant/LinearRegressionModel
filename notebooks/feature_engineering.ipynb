# %%
import pandas as pd
import numpy as np

pd.set_option('display.max_columns', 200)

from sklearn.experimental import enable_iterative_imputer  
from sklearn.impute import IterativeImputer, SimpleImputer
from sklearn.compose import ColumnTransformer

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('notebooks/coaster_cleaned.csv')

# %%
df.head()
# Out:
#                              Coaster_Name                        Location  \
# 0                      Switchback Railway                    Coney Island
# 1                       Flip Flap Railway                   Sea Lion Park
# 2  Switchback Railway (Euclid Beach Park)  Cleveland, Ohio, United States
# 3            Loop the Loop (Coney Island)                           Other
# 4            Loop the Loop (Young's Pier)                           Other
#
#     Status            Manufacturer  Year_Introduced  Latitude  Longitude  \
# 0  Removed  LaMarcus Adna Thompson             1884   40.5740   -73.9780
# 1  Removed            Lina Beecher             1895   40.5780   -73.9790
# 2   Closed                     NaN             1896   41.5800   -81.5700
# 3  Removed          Edwin Prescott             1901   40.5745   -73.9780
# 4  Removed          Edwin Prescott             1901   39.3538   -74.4342
#
#   Type_Main Opening_Date  Speed_mph  Height_ft  Inversions  Gforce
# 0      Wood   1884-06-16        6.0        NaN           0     2.9
# 1      Wood   1895-01-01        NaN        NaN           1    12.0
# 2     Other          NaN        NaN        NaN           0     NaN
# 3     Steel   1901-01-01        NaN        NaN           1     NaN
# 4     Steel   1901-01-01        NaN        NaN           1     NaN

# %%
df = df.drop('Status', axis=1)

# %%
df.columns
# Out:
# Index(['Coaster_Name', 'Location', 'Manufacturer', 'Year_Introduced',
#        'Latitude', 'Longitude', 'Type_Main', 'Opening_Date', 'Speed_mph',
#        'Height_ft', 'Inversions', 'Gforce'],
#       dtype='object')

# %%
num_cols = df.select_dtypes(include=['number']).columns
cat_cols = df.select_dtypes(include=['object', 'category']).columns

# %%
num_imp = IterativeImputer(random_state=42)
cat_imp = SimpleImputer(strategy='most_frequent')

# %%
preprocessor = ColumnTransformer([
    ('num', num_imp, num_cols),
    ('cat', cat_imp, cat_cols)
])

# %%
df_imputed = preprocessor.fit_transform(df)

# %%
df_imputed = pd.DataFrame(df_imputed, columns=num_cols.tolist() + cat_cols.tolist())

# %%
df = df_imputed

# %%
df.head()
# Out:
#   Year_Introduced Latitude Longitude   Speed_mph   Height_ft Inversions  \
# 0          1884.0   40.574   -73.978         6.0  -39.805827        0.0
# 1          1895.0   40.578   -73.979  153.513794  362.111776        1.0
# 2          1896.0    41.58    -81.57   36.227781   44.265966        0.0
# 3          1901.0  40.5745   -73.978   38.249314   50.755251        1.0
# 4          1901.0  39.3538  -74.4342   38.312525   50.913806        1.0
#
#      Gforce                            Coaster_Name  \
# 0       2.9                      Switchback Railway
# 1      12.0                       Flip Flap Railway
# 2  4.122628  Switchback Railway (Euclid Beach Park)
# 3  4.254852            Loop the Loop (Coney Island)
# 4  4.250597            Loop the Loop (Young's Pier)
#
#                          Location            Manufacturer Type_Main  \
# 0                    Coney Island  LaMarcus Adna Thompson      Wood
# 1                   Sea Lion Park            Lina Beecher      Wood
# 2  Cleveland, Ohio, United States                  Vekoma     Other
# 3                           Other          Edwin Prescott     Steel
# 4                           Other          Edwin Prescott     Steel
#
#   Opening_Date
# 0   1884-06-16
# 1   1895-01-01
# 2   1999-01-01
# 3   1901-01-01
# 4   1901-01-01

# %%
df.isna().sum()
# Out:
# Year_Introduced    0
# Latitude           0
# Longitude          0
# Speed_mph          0
# Height_ft          0
# Inversions         0
# Gforce             0
# Coaster_Name       0
# Location           0
# Manufacturer       0
# Type_Main          0
# Opening_Date       0
# dtype: int64

# %%
df.dtypes
# Out:
# Year_Introduced    object
# Latitude           object
# Longitude          object
# Speed_mph          object
# Height_ft          object
# Inversions         object
# Gforce             object
# Coaster_Name       object
# Location           object
# Manufacturer       object
# Type_Main          object
# Opening_Date       object
# dtype: object

# %%
df['Year_Introduced'] = pd.to_numeric(df['Year_Introduced']).astype(int)
df['Latitude'] = pd.to_numeric(df['Latitude'])
df['Longitude'] = pd.to_numeric(df['Longitude'])
df['Speed_mph'] = pd.to_numeric(df['Speed_mph']).astype(int)
df['Height_ft'] = pd.to_numeric(df['Height_ft']).astype(int)
df['Inversions'] = pd.to_numeric(df['Inversions']).astype(int)
df['Gforce'] = pd.to_numeric(df['Gforce'])
df['Opening_Date'] = pd.to_datetime(df['Opening_Date'])

# %%
df.dtypes
# Out:
# Year_Introduced             int64
# Latitude                  float64
# Longitude                 float64
# Speed_mph                   int64
# Height_ft                   int64
# Inversions                  int64
# Gforce                    float64
# Coaster_Name               object
# Location                   object
# Manufacturer               object
# Type_Main                  object
# Opening_Date       datetime64[ns]
# dtype: object

# %%
df.columns
# Out:
# Index(['Year_Introduced', 'Latitude', 'Longitude', 'Speed_mph', 'Height_ft',
#        'Inversions', 'Gforce', 'Coaster_Name', 'Location', 'Manufacturer',
#        'Type_Main', 'Opening_Date'],
#       dtype='object')

# %%
df = df[['Coaster_Name', 'Location', 'Manufacturer',
       'Type_Main', 'Year_Introduced', 'Latitude', 'Longitude', 'Speed_mph', 'Height_ft',
       'Inversions', 'Gforce', 'Opening_Date']]

# %%
df
# Out:
#                                Coaster_Name                        Location  \
# 0                        Switchback Railway                    Coney Island
# 1                         Flip Flap Railway                   Sea Lion Park
# 2    Switchback Railway (Euclid Beach Park)  Cleveland, Ohio, United States
# 3              Loop the Loop (Coney Island)                           Other
# 4              Loop the Loop (Young's Pier)                           Other
# ..                                      ...                             ...
# 985            Ice Breaker (roller coaster)                SeaWorld Orlando
# 986                   Leviathan (Sea World)                       Sea World
# 987               Pantheon (roller coaster)      Busch Gardens Williamsburg
# 988                                 Tumbili                  Kings Dominion
# 989          Wonder Woman Flight of Courage        Six Flags Magic Mountain
#
#                     Manufacturer Type_Main  Year_Introduced   Latitude  \
# 0         LaMarcus Adna Thompson      Wood             1884  40.574000
# 1                   Lina Beecher      Wood             1895  40.578000
# 2                         Vekoma     Other             1896  41.580000
# 3                 Edwin Prescott     Steel             1901  40.574500
# 4                 Edwin Prescott     Steel             1901  39.353800
# ..                           ...       ...              ...        ...
# 985                Premier Rides     Steel             2022  28.408800
# 986           Martin & Vleminckx      Wood             2022 -27.957400
# 987                      Intamin     Steel             2022  37.233900
# 988    S&S – Sansei Technologies     Steel             2022  37.749929
# 989  Rocky Mountain Construction     Steel             2022  37.033898
#
#       Longitude  Speed_mph  Height_ft  Inversions     Gforce Opening_Date
# 0    -73.978000          6        -39           0   2.900000   1884-06-16
# 1    -73.979000        153        362           1  12.000000   1895-01-01
# 2    -81.570000         36         44           0   4.122628   1999-01-01
# 3    -73.978000         38         50           1   4.254852   1901-01-01
# 4    -74.434200         38         50           1   4.250597   1901-01-01
# ..          ...        ...        ...         ...        ...          ...
# 985  -81.463300         52        112           0   3.181643   2022-02-01
# 986  153.426300         49        105           0   3.119106   2022-01-01
# 987  -76.642600         73        169           2   4.151077   2022-01-01
# 988  -29.022480         34         64           0   2.699946   1999-01-01
# 989  -25.981395         58        129           3   3.837332   2022-01-01
#
# [990 rows x 12 columns]

# %%
df.to_csv('data/featured_coaster_data.csv', index=False)
